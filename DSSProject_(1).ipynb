# %% [markdown]
# <a href="https://colab.research.google.com/github/owen-shaffer/DataScience-Project/blob/main/DSSProject_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/owen-shaffer/DataScience-Project
# Out:
# Cloning into 'DataScience-Project'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 33 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 2.40 MiB | 5.21 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import json
import csv
import pandas as pd
import sqlite3

# %%
import json
import csv
import pandas as pd
import sqlite3

def convert_csv_to_json(csv_file, json_file):
    with open(csv_file, 'r') as s:
      df = pd.read_csv(s)
      df.to_json(json_file, orient='records')

convert_csv_to_json('/content/DataScience-Project/AnimalDiversityNewYork.json', 'AnimalDiversityNewYork.csv')

with open('/content/DataScience-Project/AnimalDiversityNewYork.json', 'r') as f:
     animal_json = json.load(f)
     df = pd.DataFrame(animal_json['data'])
     #remove first 7 columns
     df = df.drop(df.columns[0:8], axis=1)
     df.head()

 #Conversion

choice = input("Want to convert your data to csv (1) or sql (2)")
if choice == '1':
   df.to_csv('AnimalDiversityNewYork.csv')
if choice == '2':
   df.to_sql('AnimalDiversityNewYork.db', con=sqlite3.connect('AnimalDiversityNewYork.db'))


with open('/content/DataScience-Project/SanFranPlastic.csv', 'r') as s:
     df = pd.read_csv(s)

choice = input("Want to convert your data to json (1) or sql (2)")
if choice == '1':
   df.to_json('SanFranPlastic.csv')
if choice == '2':
   df.to_sql('SanFranPlastic.db', con=sqlite3.connect('SanFranPlastic.db'))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-55-08ef79bb4776> in <cell line: 11>()
#       9       df.to_json(json_file, orient='records')
#      10
# ---> 11 convert_csv_to_json('/content/DataScience-Project/AnimalDiversityNewYork.json', 'AnimalDiversityNewYork.csv')
#      12
#      13 with open('/content/DataScience-Project/AnimalDiversityNewYork.json', 'r') as f:
#
# <ipython-input-55-08ef79bb4776> in convert_csv_to_json(csv_file, json_file)
#       6 def convert_csv_to_json(csv_file, json_file):
#       7     with open(csv_file, 'r') as s:
# ----> 8       df = pd.read_csv(s)
#       9       df.to_json(json_file, orient='records')
#      10
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     624
#     625     with parser:
# --> 626         return parser.read(nrows)
#     627
#     628
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1921                     columns,
#    1922                     col_dict,
# -> 1923                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1924                     nrows
#    1925                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 4, saw 2

# %%
with open('/content/DataScience-Project/SanFranPlastic.csv', 'r') as s:
     df = pd.read_csv(s)

choice = input("Want to convert your data to json (1) or sql (2)")
if choice == '1':
   df.to_json('SanFranPlastic.json')
   print('JSON file created')
if choice == '2':
   df.to_sql('SanFranPlastic.sql', con=sqlite3.connect('SanFranPlastic.sql'))
   print('SQL file created')
# Out:
# Want to convert your data to json (1) or sql (2)2
# SQL file created

# %%
with open('/content/DataScience-Project/AnimalDiversityNewYork.json', 'r') as f:
     animal_json = json.load(f)
     df = pd.DataFrame(animal_json['data'])
#remove first 7 columns
df = df.drop(df.columns[0:8], axis=1)

# %%
df.head()
# Out:
#        8       9           10               11                       12  \
# 0  Albany  Animal  Amphibians  Frogs and Toads      Anaxyrus americanus
# 1  Albany  Animal  Amphibians  Frogs and Toads         Anaxyrus fowleri
# 2  Albany  Animal  Amphibians  Frogs and Toads          Hyla versicolor
# 3  Albany  Animal  Amphibians  Frogs and Toads  Lithobates catesbeianus
# 4  Albany  Animal  Amphibians  Frogs and Toads     Lithobates clamitans
#
#               13         14                     15          16  17  18  \
# 0  American Toad  1990-1999  Game with open season  not listed  S5  G5
# 1  Fowler's Toad  1990-1999  Game with open season  not listed  S4  G5
# 2  Gray Treefrog  1990-1999  Game with open season  not listed  S5  G5
# 3       Bullfrog  1990-1999  Game with open season  not listed  S5  G5
# 4     Green Frog  1990-1999  Game with open season  not listed  S5  G5
#
#                    19
# 0  Recently Confirmed
# 1  Recently Confirmed
# 2  Recently Confirmed
# 3  Recently Confirmed
# 4  Recently Confirmed

# %%
choice = input("Want to convert your data to csv (1) or sql (2)")
if choice == '1':
   df.to_csv('AnimalDiversityNewYork.csv')
   print('CSV file created')
if choice == '2':
   df.to_sql('AnimalDiversityNewYork.sql', con=sqlite3.connect('AnimalDiversityNewYork.sql'))
   print('SQL file created')
# Out:
# Want to convert your data to csv (1) or sql (2)2
# SQL file created
